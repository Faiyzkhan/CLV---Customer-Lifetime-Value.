# %%
##MY APPROACH

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
##Data Importing
df = pd.read_csv(r"C:\Users\faiyz\ML\CLV-CutomerLifetmeValue\Dataset\CLV_Dataset.csv")

# %%
##Exploratory Data Analysis

# %%
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
df.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
df.shape
# Out:
# (9134, 24)

# %%
df.isnull().sum()
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
df['State'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon'],
#       dtype=object)

# %%
# Data Visualisation
plt.hist(df['Customer Lifetime Value'],bins=50,color = 'skyblue',edgecolor = 'black')
# Out:
# (array([1.888e+03, 1.804e+03, 1.508e+03, 1.236e+03, 8.240e+02, 3.680e+02,
#         2.930e+02, 2.350e+02, 1.880e+02, 1.090e+02, 9.600e+01, 9.700e+01,
#         9.300e+01, 6.700e+01, 6.000e+01, 4.700e+01, 2.600e+01, 2.800e+01,
#         3.400e+01, 1.900e+01, 2.400e+01, 1.600e+01, 1.000e+01, 1.000e+01,
#         1.500e+01, 5.000e+00, 6.000e+00, 5.000e+00, 1.000e+00, 3.000e+00,
#         3.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 4.000e+00, 0.000e+00,
#         3.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([ 1898.007675 ,  3526.5551453,  5155.1026156,  6783.6500859,
#          8412.1975562, 10040.7450265, 11669.2924968, 13297.8399671,
#         14926.3874374, 16554.9349077, 18183.482378 , 19812.0298483,
#         21440.5773186, 23069.1247889, 24697.6722592, 26326.2197295,
#         27954.7671998, 29583.3146701, 31211.8621404, 32840.4096107,
# ...

# %%
sns.scatterplot(data = df , x='Income',y='Customer Lifetime Value')
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Customer Lifetime Value'>

# %%
sns.regplot(data = df , x='Income',y='Customer Lifetime Value')
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Customer Lifetime Value'>

# %%
sns.jointplot(data = df , x='Income',y='Customer Lifetime Value')

# %%
##EmploymentStatus
sns.jointplot(data = df , x='EmploymentStatus',y='Customer Lifetime Value')
##EmploymentStatus stromgly correlated

# %%
sns.jointplot(data = df , x='Income',y='Customer Lifetime Value')

# %%
# DATA PREPROCESSING

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['State'] = le.fit_transform(df['State'])

# %%
df['State']
# Out:
# 0       4
# 1       0
# 2       2
# 3       1
# 4       4
#        ..
# 9129    1
# 9130    1
# 9131    1
# 9132    1
# 9133    1
# Name: State, Length: 9134, dtype: int32

# %%
df['Response'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Response'] = le.fit_transform(df['Response'])

# %%
df['Response']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9129    0
# 9130    1
# 9131    0
# 9132    0
# 9133    0
# Name: Response, Length: 9134, dtype: int32

# %%
df['Coverage'].unique()
# Out:
# array(['Basic', 'Extended', 'Premium'], dtype=object)

# %%
df['Education'].unique()
# Out:
# array(['Bachelor', 'College', 'Master', 'High School or Below', 'Doctor'],
#       dtype=object)

# %%
df['Policy Type'].unique()
# Out:
# array(['Corporate Auto', 'Personal Auto', 'Special Auto'], dtype=object)

# %%
df['Vehicle Size'].unique()
# Out:
# array(['Medsize', 'Small', 'Large'], dtype=object)

# %%
df['Coverage'] = le.fit_transform(df['Coverage'])
df['Education'] = le.fit_transform(df['Education'])##
df['EmploymentStatus'] = le.fit_transform(df['EmploymentStatus'])
df['Gender'] = le.fit_transform(df['Gender'])
df['Policy Type'] = le.fit_transform(df['Policy Type'])
df['Policy'] = le.fit_transform(df['Policy'])
df['Vehicle Size'] = le.fit_transform(df['Vehicle Size'])
df['Vehicle Class'] = le.fit_transform(df['Vehicle Class'])
df['Sales Channel'] = le.fit_transform(df['Sales Channel'])
df['Renew Offer Type'] = le.fit_transform(df['Renew Offer Type'])
df['Location Code'] = le.fit_transform(df['Location Code'])
df['Marital Status'] = le.fit_transform(df['Marital Status'])

# %%
df
# Out:
#      Customer  State  Customer Lifetime Value  Response  Coverage  Education  \
# 0     BU79786      4              2763.519279         0         0          0
# 1     QZ44356      0              6979.535903         0         1          0
# 2     AI49188      2             12887.431650         0         2          0
# 3     WW63253      1              7645.861827         0         0          0
# 4     HB64268      4              2813.692575         0         0          0
# ...       ...    ...                      ...       ...       ...        ...
# 9129  LA72316      1             23405.987980         0         0          0
# 9130  PK87824      1              3096.511217         1         1          1
# 9131  TD14365      1              8163.890428         0         1          0
# 9132  UP19263      1              7524.442436         0         1          1
# 9133  Y167826      1              2611.836866         0         1          1
#
# ...

# %%
df['Effective To Date'] = pd.to_datetime(df['Effective To Date'], format='%m/%d/%y')
df['year'] = df['Effective To Date'].dt.year
df['month'] = df['Effective To Date'].dt.month
df['day'] = df['Effective To Date'].dt.day

# %%
df.drop(columns=['Effective To Date'], inplace=True)

# %%
df
# Out:
#      Customer  State  Customer Lifetime Value  Response  Coverage  Education  \
# 0     BU79786      4              2763.519279         0         0          0
# 1     QZ44356      0              6979.535903         0         1          0
# 2     AI49188      2             12887.431650         0         2          0
# 3     WW63253      1              7645.861827         0         0          0
# 4     HB64268      4              2813.692575         0         0          0
# ...       ...    ...                      ...       ...       ...        ...
# 9129  LA72316      1             23405.987980         0         0          0
# 9130  PK87824      1              3096.511217         1         1          1
# 9131  TD14365      1              8163.890428         0         1          0
# 9132  UP19263      1              7524.442436         0         1          1
# 9133  Y167826      1              2611.836866         0         1          1
#
# ...

# %%
df_enc = df

# %%
df_enc['Customer'] = df['Customer']

# %%
df_enc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   int32
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   int32
#  4   Coverage                       9134 non-null   int32
#  5   Education                      9134 non-null   int32
#  6   EmploymentStatus               9134 non-null   int32
#  7   Gender                         9134 non-null   int32
#  8   Income                         9134 non-null   int64
#  9   Location Code                  9134 non-null   int32
#  10  Marital Status                 9134 non-null   int32
#  11  Monthly Premium Auto           9134 non-null   int64
# ...

# %%
df = df_enc

# %%
df_enc.drop('Customer',axis=1 , inplace = True)

# %%
df_enc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          9134 non-null   int32
#  1   Customer Lifetime Value        9134 non-null   float64
#  2   Response                       9134 non-null   int32
#  3   Coverage                       9134 non-null   int32
#  4   Education                      9134 non-null   int32
#  5   EmploymentStatus               9134 non-null   int32
#  6   Gender                         9134 non-null   int32
#  7   Income                         9134 non-null   int64
#  8   Location Code                  9134 non-null   int32
#  9   Marital Status                 9134 non-null   int32
#  10  Monthly Premium Auto           9134 non-null   int64
#  11  Months Since Last Claim        9134 non-null   int64
# ...

# %%
# CORRELATED
sns.jointplot(data = df , x='Vehicle Size',y='Customer Lifetime Value')

# %%
sns.jointplot(data = df , x='year',y='Customer Lifetime Value')

# %%
sns.jointplot(data = df , x='Total Claim Amount',y='Customer Lifetime Value')

# %%
sns.pairplot(df[['Policy', 'Income', 'State', 'Gender']], hue='Gender')
plt.show()

# %%
selected_cols = 'Income'[:5]  # Choose 5 to start with
sns.pairplot(df['Income'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16996/1936474981.py in <module>
#       1 selected_cols = 'Income'[:5]  # Choose 5 to start with
# ----> 2 sns.pairplot(df['Income'])
#       3 plt.show()
#
# ~\miniconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2096
#    2097     if not isinstance(data, pd.DataFrame):
# -> 2098         raise TypeError(
#    2099             f"'data' must be pandas DataFrame object, not: {type(data)}")
#    2100
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'pandas.core.series.Series'>

# %%
df_enc.corr()
# Out:
#                                   State  Customer Lifetime Value  Response  \
# State                          1.000000                 0.008778 -0.002473
# Customer Lifetime Value        0.008778                 1.000000 -0.008930
# Response                      -0.002473                -0.008930  1.000000
# Coverage                       0.002047                 0.168040  0.000642
# Education                      0.015755                 0.026038  0.000285
# EmploymentStatus               0.000368                -0.034846 -0.016703
# Gender                        -0.004933                -0.013610  0.004396
# Income                         0.004620                 0.024366  0.011932
# Location Code                 -0.005240                 0.004854  0.001729
# Marital Status                 0.020371                -0.026003 -0.094843
# Monthly Premium Auto           0.007898                 0.396262  0.010966
# ...

# %%
correlation_metrics = df_enc.corr()
fig = plt.figure(figsize = (14,9))
sns.heatmap(correlation_metrics, vmax = 9, square = True)
plt.show()
print(correlation_metrics)
# Out:
#                                   State  Customer Lifetime Value  Response  \
# State                          1.000000                 0.008778 -0.002473
# Customer Lifetime Value        0.008778                 1.000000 -0.008930
# Response                      -0.002473                -0.008930  1.000000
# Coverage                       0.002047                 0.168040  0.000642
# Education                      0.015755                 0.026038  0.000285
# EmploymentStatus               0.000368                -0.034846 -0.016703
# Gender                        -0.004933                -0.013610  0.004396
# Income                         0.004620                 0.024366  0.011932
# Location Code                 -0.005240                 0.004854  0.001729
# Marital Status                 0.020371                -0.026003 -0.094843
# Monthly Premium Auto           0.007898                 0.396262  0.010966
# ...

# %%
# Train Test Split
from sklearn.model_selection import train_test_split

# %%
x = df_enc[['Education','Coverage','EmploymentStatus','Gender','Income','Monthly Premium Auto','Months Since Last Claim','Total Claim Amount','Vehicle Class']]
y = df_enc['Customer Lifetime Value']

# %%
y_log = np.log(df_enc['Customer Lifetime Value' ])
x_train,x_test , y_train , y_test = train_test_split(x,y_log,test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(x_test)

# %%
pred
# Out:
# array([8.90060641, 8.61086773, 8.82629016, ..., 9.15725204, 8.56595595,
#        9.08359887])

# %%
sns.regplot(
    x=pred,
    y=y_test,
    scatter_kws={'alpha': 0.6}
)
plt.xlabel('Predictions')
# Out:
# Text(0.5, 0, 'Predictions')

# %%
residual = y_test - pred
print(residual)
# Out:
# 708    -0.552393
# 47      0.004240
# 3995   -0.581399
# 1513    0.168607
# 3686    0.418205
#           ...
# 4271   -0.619907
# 7923    0.121107
# 5633   -0.540662
# 8432   -0.030240
# 681     1.198132
# Name: Customer Lifetime Value, Length: 2741, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error 
import math

print("Mean Absolute Error:", mean_absolute_error(y_test,pred) )
print("Mean Squared Error:" , mean_squared_error(y_test,pred))
print("RMSE:" , math.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Mean Absolute Error: 0.46243812174206794
# Mean Squared Error: 0.3557207487670282
# RMSE: 0.5964232966333795

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, pred)
print("R²:", r2)
# Out:
# R²: 0.20446758652437558

# %%
# MODEL BUILDING USING RANDOM FOREST
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
model = RandomForestRegressor(n_estimators=200, random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
r_pred = model.predict(x_test)

# %%
sns.regplot(
            x = r_pred,
            y = y_test)
# Out:
# <AxesSubplot:ylabel='Customer Lifetime Value'>

# %%
residual = y_test - pred
print(residual)
# Out:
# 708    -0.552393
# 47      0.004240
# 3995   -0.581399
# 1513    0.168607
# 3686    0.418205
#           ...
# 4271   -0.619907
# 7923    0.121107
# 5633   -0.540662
# 8432   -0.030240
# 681     1.198132
# Name: Customer Lifetime Value, Length: 2741, dtype: float64

# %%
print("Mean Absolute Error:", mean_absolute_error(y_test,pred) )
print("Mean Squared Error:" , mean_squared_error(y_test,pred))
print("RMSE:" , math.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Mean Absolute Error: 0.46243812174206794
# Mean Squared Error: 0.3557207487670282
# RMSE: 0.5964232966333795

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, pred)
print("R²:", r2)
# Out:
# R²: 0.20446758652437558

# %%
# Out:
# 0        7.924260
# 1        8.850738
# 2        9.464008
# 3        8.941920
# 4        7.942253
#           ...
# 9129    10.060747
# 9130     8.038031
# 9131     9.007476
# 9132     8.925912
# 9133     7.867809
# Name: Customer Lifetime Value, Length: 9134, dtype: float64
